# %%
import numpy as np
import pandas as pd
import matplotlib.pylab as plt

# %%
id2 = "../data/id000002-EL.csv" #find pandas from module 2 and load same way
column_names = ['t', 'a', 'e', 'i', 'omega', 'varpi', 'f', 'rp', 'ra']
id3 = "../data/id000003-EL.csv"
id4 = "../data/id000004-EL.csv"
id5 = "../data/id000005-EL.csv"
id6 = "../data/id000006-EL.csv"
id7 = "../data/id000007-EL.csv"
id8 = "../data/id000008-EL.csv"
id9 = "../data/id000009-EL.csv"
id10 = "../data/id000010-EL.csv"
df2 = pd.read_csv(id2, names=column_names, sep=r'\s+')
df3 = pd.read_csv(id3, names=column_names, sep=r'\s+')
df4 = pd.read_csv(id4, names=column_names, sep=r'\s+')
df5 = pd.read_csv(id5, names=column_names, sep=r'\s+')
df6 = pd.read_csv(id6, names=column_names, sep=r'\s+')
df7 = pd.read_csv(id7, names=column_names, sep=r'\s+')
df8 = pd.read_csv(id8, names=column_names, sep=r'\s+')
df9 = pd.read_csv(id9, names=column_names, sep=r'\s+')
df10 = pd.read_csv(id10, names=column_names, sep=r'\s+')

df10
# Out:
#                 t             a         e         i     omega     varpi  \
# 0             0.0  5.214881e+12  0.196752  0.299573  1.924896  3.343124
# 1        365250.0  5.277237e+12  0.218999  0.299472  1.923312 -2.729688
# 2        730500.0  5.343531e+12  0.231837  0.298709  1.921576 -2.570963
# 3       1095750.0  5.342570e+12  0.240386  0.299614  1.921432 -2.450026
# 4       1461000.0  5.349242e+12  0.254072  0.299911  1.920698 -2.347308
# ...           ...           ...       ...       ...       ...       ...
# 996   363789000.0  5.399901e+12  0.226793  0.294217  0.360164 -4.299552
# 997   364154250.0  5.427545e+12  0.232639  0.294202  0.358630 -4.164920
# 998   364519500.0  5.416614e+12  0.246397  0.295176  0.358658 -4.033022
# 999   364884750.0  5.443561e+12  0.257891  0.294301  0.354327 -3.881031
# 1000  365250000.0  5.490171e+12  0.258999  0.293974  0.350839 -3.694148
#
#              f            rp            ra
# 0     1.513041  4.188842e+12  6.240920e+12
# ...

# %%
fig, axs = plt.subplots(9, 2)
axs[0,0].plot(df2['t'], df2['e'])
axs[0,0].set_title("Eccentricity of Mercury")
axs[0,1].plot(df2['t'], df2['i'])
axs[0,1].set_title("Inclination of Mercury")
axs[1,0].plot(df3['t'], df3['e'])
axs[1,0].set_title("Eccentricity of Venus")
axs[1,1].plot(df3['t'], df3['i'])
axs[1,1].set_title("Inclination of Venus")
axs[2,0].plot(df4['t'], df4['e'])
axs[2,0].set_title("Eccentricity of Earth")
axs[2,1].plot(df4['t'], df4['i'])
axs[2,1].set_title("Inclination of Earth")
axs[3,0].plot(df5['t'], df5['e'])
axs[3,0].set_title("Eccentricity of Mars")
axs[3,1].plot(df5['t'], df5['i'])
axs[3,1].set_title("Inclination of Mars")
axs[4,0].plot(df6['t'], df6['e'])
axs[4,0].set_title("Eccentricity of Jupiter")
axs[4,1].plot(df6['t'], df6['i'])
axs[4,1].set_title("Inclination of Jupiter")
axs[5,0].plot(df7['t'], df7['e'])
axs[5,0].set_title("Eccentricity of Saturn")
axs[5,1].plot(df7['t'], df7['i'])
axs[5,1].set_title("Inclination of Saturn")
axs[6,0].plot(df8['t'], df8['e'])
axs[6,0].set_title("Eccentricity of Uranus")
axs[6,1].plot(df8['t'], df8['i'])
axs[6,1].set_title("Inclination of Uranus")
axs[7,0].plot(df9['t'], df9['e'])
axs[7,0].set_title("Eccentricity of Neptune")
axs[7,1].plot(df9['t'], df9['i'])
axs[7,1].set_title("Inclination of Neptune")
axs[8,0].plot(df10['t'], df10['e'])
axs[8,0].set_title("Eccentricity of Pluto")
axs[8,1].plot(df10['t'], df10['i'])
axs[8,1].set_title("Inclination of Pluto")

plt.rcParams['figure.figsize'] = [30, 30]

# %%
fig, axs = plt.subplots(9, 2)
axs[0,0].plot(df2['a'], df2['e'])
axs[0,0].set_title("Eccentricity of Mercury")
axs[0,1].plot(df2['a'], df2['i'])
axs[0,1].set_title("Inclination of Mercury")
axs[1,0].plot(df3['a'], df3['e'])
axs[1,0].set_title("Eccentricity of Venus")
axs[1,1].plot(df3['a'], df3['i'])
axs[1,1].set_title("Inclination of Venus")
axs[2,0].plot(df4['a'], df4['e'])
axs[2,0].set_title("Eccentricity of Earth")
axs[2,1].plot(df4['a'], df4['i'])
axs[2,1].set_title("Inclination of Earth")
axs[3,0].plot(df5['a'], df5['e'])
axs[3,0].set_title("Eccentricity of Mars")
axs[3,1].plot(df5['a'], df5['i'])
axs[3,1].set_title("Inclination of Mars")
axs[4,0].plot(df6['a'], df6['e'])
axs[4,0].set_title("Eccentricity of Jupiter")
axs[4,1].plot(df6['a'], df6['i'])
axs[4,1].set_title("Inclination of Jupiter")
axs[5,0].plot(df7['a'], df7['e'])
axs[5,0].set_title("Eccentricity of Saturn")
axs[5,1].plot(df7['a'], df7['i'])
axs[5,1].set_title("Inclination of Saturn")
axs[6,0].plot(df8['a'], df8['e'])
axs[6,0].set_title("Eccentricity of Uranus")
axs[6,1].plot(df8['a'], df8['i'])
axs[6,1].set_title("Inclination of Uranus")
axs[7,0].plot(df9['a'], df9['e'])
axs[7,0].set_title("Eccentricity of Neptune")
axs[7,1].plot(df9['a'], df9['i'])
axs[7,1].set_title("Inclination of Neptune")
axs[8,0].plot(df10['a'], df10['e'])
axs[8,0].set_title("Eccentricity of Pluto")
axs[8,1].plot(df10['a'], df10['i'])
axs[8,1].set_title("Inclination of Pluto")

plt.rcParams['figure.figsize'] = [30, 30]

# %%
plt.plot(df2['t'], df2['a'], label='2')
plt.plot(df3['t'], df3['a'], label='3')
plt.plot(df4['t'], df4['a'], label='4')
plt.plot(df5['t'], df5['a'], label='5')
plt.plot(df6['t'], df6['a'], label='6')
plt.plot(df7['t'], df7['a'], label='7')
plt.plot(df8['t'], df8['a'], label='8')
plt.plot(df9['t'], df9['a'], label='9')
plt.plot(df10['t'], df10['a'], label='10')

plt.fill_between(df2['t'], df2['rp'], df2['ra'], alpha=0.5)
plt.fill_between(df3['t'], df3['rp'], df3['ra'], alpha=0.5)
plt.fill_between(df4['t'], df4['rp'], df4['ra'], alpha=0.5)
plt.fill_between(df5['t'], df5['rp'], df5['ra'], alpha=0.5)
plt.fill_between(df6['t'], df6['rp'], df6['ra'], alpha=0.5)
plt.fill_between(df7['t'], df7['rp'], df7['ra'], alpha=0.5)
plt.fill_between(df8['t'], df8['rp'], df8['ra'], alpha=0.5)
plt.fill_between(df9['t'], df9['rp'], df9['ra'], alpha=0.5)
plt.fill_between(df10['t'], df10['rp'], df10['ra'], alpha=0.5)

plt.yscale('log')
plt.legend()
