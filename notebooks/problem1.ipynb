# %%
import numpy as np
import pandas as pd
import matplotlib.pylab as plt

# %%
id2 = "../data/id000002-XV.csv"
id3 = "../data/id000003-XV.csv"
id4 = "../data/id000004-XV.csv"
id5 = "../data/id000005-XV.csv"
id6 = "../data/id000006-XV.csv"
id7 = "../data/id000007-XV.csv"
id8 = "../data/id000008-XV.csv"
id9 = "../data/id000009-XV.csv"
id10 = "../data/id000010-XV.csv"
df2 = pd.read_csv(id2)
df3 = pd.read_csv(id3)
df4 = pd.read_csv(id4)
df5 = pd.read_csv(id5)
df6 = pd.read_csv(id6)
df7 = pd.read_csv(id7)
df8 = pd.read_csv(id8)
df9 = pd.read_csv(id9)
df10 = pd.read_csv(id10)

df10
# Out:
#                 t         xh         yh         zh       vxh       vyh  \
# 0             0.0   4.913468 -31.886966   1.991604  0.003156 -0.000146
# 1        365250.0  13.180904 -31.342850  -0.478250  0.002965  0.000539
# 2        730500.0  19.642578 -29.555161  -2.552797  0.002708  0.001036
# 3       1095750.0  25.031516 -26.988829  -4.398293  0.002404  0.001408
# 4       1461000.0  29.599166 -23.853609  -6.069889  0.002101  0.001680
# ...           ...        ...        ...        ...       ...       ...
# 996   363789000.0 -33.872957 -18.991621  -1.768166  0.000767 -0.002556
# 997   364154250.0 -31.316790 -25.287133  -3.843917  0.001185 -0.002277
# 998   364519500.0 -27.134480 -31.645590  -6.113765  0.001554 -0.001903
# 999   364884750.0 -21.075023 -37.497413  -8.443195  0.001866 -0.001460
# 1000  365250000.0 -12.544823 -42.419395 -10.754708  0.002120 -0.000896
#
#             vz
# 0    -0.000899
# 1    -0.000917
# 2    -0.000893
# 3    -0.000847
# 4    -0.000788
# ...        ...
# ...

# %%
for df in [df2, df3, df4, df5, df6, df7, df8, df9, df10]:
    plt.plot(df['xh'], df['yh'])

# %%
for df in [df2, df3, df4, df5, df6, df7, df8, df9, df10]:
    plt.plot(df['xh'], df['zh'])

# %%
ax = df2.plot(x='xh', y='yh', label='2')

# %%
ax = df2.plot(x='xh', y='yh', label='2')
df3.plot(ax=ax, x='xh', y='yh', label='3')
# Out:
# <AxesSubplot:xlabel='xh'>

# %%
ax = df2.plot(x='xh', y='yh', label='2')
df3.plot(ax=ax, x='xh', y='yh', label='3')
df4.plot(ax=ax, x='xh', y='yh', label='4')
# Out:
# <AxesSubplot:xlabel='xh'>

# %%
ax = df2.plot(x='xh', y='yh', label='2')
df3.plot(ax=ax, x='xh', y='yh', label='3')
df4.plot(ax=ax, x='xh', y='yh', label='4')
df5.plot(ax=ax, x='xh', y='yh', label='5')
# Out:
# <AxesSubplot:xlabel='xh'>

# %%
ax = df2.plot(x='xh', y='yh', label='2')
df3.plot(ax=ax, x='xh', y='yh', label='3')
df4.plot(ax=ax, x='xh', y='yh', label='4')
df5.plot(ax=ax, x='xh', y='yh', label='5')
df6.plot(ax=ax, x='xh', y='yh', label='6')
df7.plot(ax=ax, x='xh', y='yh', label='7')
df8.plot(ax=ax, x='xh', y='yh', label='8')
df9.plot(ax=ax, x='xh', y='yh', label='9')
df10.plot(ax=ax, x='xh', y='yh', label='10')
# Out:
# <AxesSubplot:xlabel='xh'>

# %%
ax = df2.plot(x='xh', y='zh', label='2')

# %%
ax = df2.plot(x='xh', y='zh', label='2')
df3.plot(ax=ax, x='xh', y='zh', label='3')
# Out:
# <AxesSubplot:xlabel='xh'>

# %%
ax = df2.plot(x='xh', y='zh', label='2')
df3.plot(ax=ax, x='xh', y='zh', label='3')
df4.plot(ax=ax, x='xh', y='zh', label='4')
# Out:
# <AxesSubplot:xlabel='xh'>

# %%
ax = df2.plot(x='xh', y='zh', label='2')
df3.plot(ax=ax, x='xh', y='zh', label='3')
df4.plot(ax=ax, x='xh', y='zh', label='4')
df5.plot(ax=ax, x='xh', y='zh', label='5')
# Out:
# <AxesSubplot:xlabel='xh'>

# %%
ax = df2.plot(x='xh', y='zh', label='2')
df3.plot(ax=ax, x='xh', y='zh', label='3')
df4.plot(ax=ax, x='xh', y='zh', label='4')
df5.plot(ax=ax, x='xh', y='zh', label='5')
df6.plot(ax=ax, x='xh', y='zh', label='6')
# Out:
# <AxesSubplot:xlabel='xh'>

# %%
ax = df2.plot(x='xh', y='zh', label='2')
df3.plot(ax=ax, x='xh', y='zh', label='3')
df4.plot(ax=ax, x='xh', y='zh', label='4')
df5.plot(ax=ax, x='xh', y='zh', label='5')
df6.plot(ax=ax, x='xh', y='zh', label='6')
df7.plot(ax=ax, x='xh', y='zh', label='7')
# Out:
# <AxesSubplot:xlabel='xh'>

# %%
ax = df2.plot(x='xh', y='zh', label='2')
df3.plot(ax=ax, x='xh', y='zh', label='3')
df4.plot(ax=ax, x='xh', y='zh', label='4')
df5.plot(ax=ax, x='xh', y='zh', label='5')
df6.plot(ax=ax, x='xh', y='zh', label='6')
df7.plot(ax=ax, x='xh', y='zh', label='7')
df8.plot(ax=ax, x='xh', y='zh', label='8')
# Out:
# <AxesSubplot:xlabel='xh'>

# %%
ax = df2.plot(x='xh', y='zh', label='2')
df3.plot(ax=ax, x='xh', y='zh', label='3')
df4.plot(ax=ax, x='xh', y='zh', label='4')
df5.plot(ax=ax, x='xh', y='zh', label='5')
df6.plot(ax=ax, x='xh', y='zh', label='6')
df7.plot(ax=ax, x='xh', y='zh', label='7')
df8.plot(ax=ax, x='xh', y='zh', label='8')
df9.plot(ax=ax, x='xh', y='zh', label='9')
# Out:
# <AxesSubplot:xlabel='xh'>

# %%
ax = df2.plot(x='xh', y='zh', label='2')
df3.plot(ax=ax, x='xh', y='zh', label='3')
df4.plot(ax=ax, x='xh', y='zh', label='4')
df5.plot(ax=ax, x='xh', y='zh', label='5')
df6.plot(ax=ax, x='xh', y='zh', label='6')
df7.plot(ax=ax, x='xh', y='zh', label='7')
df8.plot(ax=ax, x='xh', y='zh', label='8')
df9.plot(ax=ax, x='xh', y='zh', label='9')
df10.plot(ax=ax, x='xh', y='zh', label='10')
# Out:
# <AxesSubplot:xlabel='xh'>
