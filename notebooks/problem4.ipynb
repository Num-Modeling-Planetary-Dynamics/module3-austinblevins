# %%
import numpy as np
import pandas as pd
import matplotlib.pylab as plt

# %%
id2 = "../data/id000002-LF.csv"
id3 = "../data/id000003-LF.csv"
id4 = "../data/id000004-LF.csv"
id5 = "../data/id000005-LF.csv"
id6 = "../data/id000006-LF.csv"
id7 = "../data/id000007-LF.csv"
id8 = "../data/id000008-LF.csv"
id9 = "../data/id000009-LF.csv"
id10 = "../data/id000010-LF.csv"
column_names = ['t', 'rx', 'ry', 'rz', 'vx', 'vy', 'vz', 'energy', 'am', 'deltae', 'deltaam']
df2 = pd.read_csv(id2, names=column_names, sep=r'\s+')
df3 = pd.read_csv(id3, names=column_names, sep=r'\s+')
df4 = pd.read_csv(id4, names=column_names, sep=r'\s+')
df5 = pd.read_csv(id5, names=column_names, sep=r'\s+')
df6 = pd.read_csv(id6, names=column_names, sep=r'\s+')
df7 = pd.read_csv(id7, names=column_names, sep=r'\s+')
df8 = pd.read_csv(id8, names=column_names, sep=r'\s+')
df9 = pd.read_csv(id9, names=column_names, sep=r'\s+')
df10 = pd.read_csv(id10, names=column_names, sep=r'\s+')

df10
# Out:
#            t            rx            ry            rz        vx         vy  \
# 0        0.0  4.913480e+00 -3.188697e+01  1.991600e+00  0.003110   0.000152
# 1    10000.0  3.173881e+04 -2.807821e+05  2.087658e+04  6.377080 -56.415777
# 2    20000.0  6.362421e+04 -5.628610e+05  4.184959e+04  6.377079 -56.415775
# 3    30000.0  9.550960e+04 -8.449398e+05  6.282259e+04  6.377079 -56.415774
# 4    40000.0  1.273950e+05 -1.127019e+06  8.379559e+04  6.377079 -56.415774
# ..       ...           ...           ...           ...       ...        ...
# 95  950000.0  3.028966e+06 -2.679620e+07  1.992339e+06  6.377079 -56.415773
# 96  960000.0  3.060851e+06 -2.707827e+07  2.013312e+06  6.377079 -56.415773
# 97  970000.0  3.092737e+06 -2.736035e+07  2.034285e+06  6.377079 -56.415773
# 98  980000.0  3.124622e+06 -2.764243e+07  2.055258e+06  6.377079 -56.415773
# 99  990000.0  3.156508e+06 -2.792451e+07  2.076231e+06  6.377079 -56.415773
#
# ...

# %%
fig, axs = plt.subplots(9, 2)
axs[0,0].plot(df2['t'], df2['energy'])
axs[0,0].set_title("Energy of Mercury")
axs[0,1].plot(df2['t'], df2['am'])
axs[0,1].set_title("Angular Momentum of Mercury")
axs[1,0].plot(df3['t'], df3['energy'])
axs[1,0].set_title("Energy of Venus")
axs[1,1].plot(df3['t'], df3['am'])
axs[1,1].set_title("Angular Momentum of Venus")
axs[2,0].plot(df4['t'], df4['energy'])
axs[2,0].set_title("Energy of Earth")
axs[2,1].plot(df4['t'], df4['am'])
axs[2,1].set_title("Angular Momentum of Earth")
axs[3,0].plot(df5['t'], df5['energy'])
axs[3,0].set_title("Energy of Mars")
axs[3,1].plot(df5['t'], df5['am'])
axs[3,1].set_title("Angular Momentum of Mars")
axs[4,0].plot(df6['t'], df6['energy'])
axs[4,0].set_title("Energy of Jupiter")
axs[4,1].plot(df6['t'], df6['am'])
axs[4,1].set_title("Angular Momentum of Jupiter")
axs[5,0].plot(df7['t'], df7['energy'])
axs[5,0].set_title("Energy of Saturn")
axs[5,1].plot(df7['t'], df7['am'])
axs[5,1].set_title("Angular Momentum of Saturn")
axs[6,0].plot(df8['t'], df8['energy'])
axs[6,0].set_title("Energy of Uranus")
axs[6,1].plot(df8['t'], df8['am'])
axs[6,1].set_title("Angular Momentum of Uranus")
axs[7,0].plot(df9['t'], df9['energy'])
axs[7,0].set_title("Energy of Neptune")
axs[7,1].plot(df9['t'], df9['am'])
axs[7,1].set_title("Angular Momentum of Neptune")
axs[8,0].plot(df10['t'], df10['energy'])
axs[8,0].set_title("Energy of Pluto")
axs[8,1].plot(df10['t'], df10['am'])
axs[8,1].set_title("Angular Momentum of Pluto")

plt.rcParams['figure.figsize'] = [30, 30]

# %%
fig, axs = plt.subplots(9, 2)
axs[0,0].plot(df2['t'], df2['deltae'])
axs[0,0].set_title("$\Delta E$ of Mercury")
axs[0,1].plot(df2['t'], df2['deltaam'])
axs[0,1].set_title("$\Delta h$ of Mercury")
axs[1,0].plot(df3['t'], df3['deltae'])
axs[1,0].set_title("$\Delta E$ of Venus")
axs[1,1].plot(df3['t'], df3['deltaam'])
axs[1,1].set_title("$\Delta h$ of Venus")
axs[2,0].plot(df4['t'], df4['deltae'])
axs[2,0].set_title("$\Delta E$ of Earth")
axs[2,1].plot(df4['t'], df4['deltaam'])
axs[2,1].set_title("$\Delta h$ of Earth")
axs[3,0].plot(df5['t'], df5['deltae'])
axs[3,0].set_title("$\Delta E$ of Mars")
axs[3,1].plot(df5['t'], df5['deltaam'])
axs[3,1].set_title("$\Delta h$ of Mars")
axs[4,0].plot(df6['t'], df6['deltae'])
axs[4,0].set_title("$\Delta E$ of Jupiter")
axs[4,1].plot(df6['t'], df6['deltaam'])
axs[4,1].set_title("$\Delta h$ of Jupiter")
axs[5,0].plot(df7['t'], df7['deltae'])
axs[5,0].set_title("$\Delta E$ of Saturn")
axs[5,1].plot(df7['t'], df7['deltaam'])
axs[5,1].set_title("$\Delta h$ of Saturn")
axs[6,0].plot(df8['t'], df8['deltae'])
axs[6,0].set_title("$\Delta E$ of Uranus")
axs[6,1].plot(df8['t'], df8['deltaam'])
axs[6,1].set_title("$\Delta h$ of Uranus")
axs[7,0].plot(df9['t'], df9['deltae'])
axs[7,0].set_title("$\Delta E$ of Neptune")
axs[7,1].plot(df9['t'], df9['deltaam'])
axs[7,1].set_title("$\Delta h$ of Neptune")
axs[8,0].plot(df10['t'], df10['deltae'])
axs[8,0].set_title("$\Delta E$ of Pluto")
axs[8,1].plot(df10['t'], df10['deltaam'])
axs[8,1].set_title("$\Delta h$ of Pluto")

plt.rcParams['figure.figsize'] = [30, 30]

# %%
fig, axs = plt.subplots(9, 2)
axs[0,0].plot(df2['rx'], df2['ry'])
axs[0,0].set_title("Rx v. Ry of Mercury")
axs[0,1].plot(df2['rx'], df2['rz'])
axs[0,1].set_title("Rx v. Rz of Mercury")
axs[1,0].plot(df3['rx'], df3['ry'])
axs[1,0].set_title("Rx v. Ry of Venus")
axs[1,1].plot(df3['rx'], df3['rz'])
axs[1,1].set_title("Rx v. Rz of Venus")
axs[2,0].plot(df4['rx'], df4['ry'])
axs[2,0].set_title("Rx v. Ry of Earth")
axs[2,1].plot(df4['rx'], df4['rz'])
axs[2,1].set_title("Rx v. Rz of Earth")
axs[3,0].plot(df5['rx'], df5['ry'])
axs[3,0].set_title("Rx v. Ry of Mars")
axs[3,1].plot(df5['rx'], df5['rz'])
axs[3,1].set_title("Rx v. Rz of Mars")
axs[4,0].plot(df6['rx'], df6['ry'])
axs[4,0].set_title("Rx v. Ry of Jupiter")
axs[4,1].plot(df6['rx'], df6['ry'])
axs[4,1].set_title("Rx v. Ry of Jupiter")
axs[5,0].plot(df7['rx'], df7['ry'])
axs[5,0].set_title("Rx v. Ry of Saturn")
axs[5,1].plot(df7['rx'], df7['rz'])
axs[5,1].set_title("Rx v. Rz of Saturn")
axs[6,0].plot(df8['rx'], df8['ry'])
axs[6,0].set_title("Rx v. Ry of Uranus")
axs[6,1].plot(df8['rx'], df8['rz'])
axs[6,1].set_title("Rx v. Rz of Uranus")
axs[7,0].plot(df9['rx'], df9['ry'])
axs[7,0].set_title("Rx v. Ry of Neptune")
axs[7,1].plot(df9['rx'], df9['rz'])
axs[7,1].set_title("Rx v. Rz of Neptune")
axs[8,0].plot(df10['rx'], df10['ry'])
axs[8,0].set_title("Rx v. Ry of Pluto")
axs[8,1].plot(df10['rx'], df10['rz'])
axs[8,1].set_title("Rx v. Rz of Pluto")

plt.rcParams['figure.figsize'] = [30, 30]
