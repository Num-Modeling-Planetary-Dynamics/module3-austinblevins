# %%
import numpy as np
import pandas as pd
import matplotlib.pylab as plt

# %%
id2 = "../data/id000002-XV-new.csv" #find pandas from module 2 and load same way
column_names = ['t', 'rx', 'ry', 'rz', 'vx', 'vy', 'vz']
id3 = "../data/id000003-XV-new.csv"
id4 = "../data/id000004-XV-new.csv"
id5 = "../data/id000005-XV-new.csv"
id6 = "../data/id000006-XV-new.csv"
id7 = "../data/id000007-XV-new.csv"
id8 = "../data/id000008-XV-new.csv"
id9 = "../data/id000009-XV-new.csv"
id10 = "../data/id000010-XV-new.csv"
df2 = pd.read_csv(id2, names=column_names, sep=r'\s+')
df3 = pd.read_csv(id3, names=column_names, sep=r'\s+')
df4 = pd.read_csv(id4, names=column_names, sep=r'\s+')
df5 = pd.read_csv(id5, names=column_names, sep=r'\s+')
df6 = pd.read_csv(id6, names=column_names, sep=r'\s+')
df7 = pd.read_csv(id7, names=column_names, sep=r'\s+')
df8 = pd.read_csv(id8, names=column_names, sep=r'\s+')
df9 = pd.read_csv(id9, names=column_names, sep=r'\s+')
df10 = pd.read_csv(id10, names=column_names, sep=r'\s+')

df10
# Out:
#                 t         rx         ry        rz        vx        vy  \
# 0             0.0   5.161282 -33.495206  2.092052  0.000091 -0.000590
# 1        365250.0  13.306488 -31.641475 -0.482807  0.000258 -0.000614
# 2        730500.0  19.240766 -28.950575 -2.500577  0.000388 -0.000584
# 3       1095750.0  23.697798 -25.550822 -4.163945  0.000492 -0.000530
# 4       1461000.0  27.173181 -21.898537 -5.572393  0.000591 -0.000476
# ...           ...        ...        ...       ...       ...       ...
# 996   363789000.0 -31.317557 -17.558880 -1.634775 -0.000592 -0.000332
# 997   364154250.0 -28.186519 -22.759556 -3.459698 -0.000537 -0.000433
# 998   364519500.0 -23.610922 -27.536239 -5.319860 -0.000470 -0.000548
# 999   364884750.0 -17.872569 -31.799495 -7.160210 -0.000363 -0.000647
# 1000  365250000.0 -10.430375 -35.269545 -8.941987 -0.000206 -0.000698
#
#             vz
# 0     0.000037
# 1    -0.000009
# 2    -0.000050
# 3    -0.000086
# 4    -0.000121
# ...        ...
# ...

# %%
id2 = "../data/id000002-XV.csv"
id3 = "../data/id000003-XV.csv"
id4 = "../data/id000004-XV.csv"
id5 = "../data/id000005-XV.csv"
id6 = "../data/id000006-XV.csv"
id7 = "../data/id000007-XV.csv"
id8 = "../data/id000008-XV.csv"
id9 = "../data/id000009-XV.csv"
id10 = "../data/id000010-XV.csv"
df2o = pd.read_csv(id2)
df3o = pd.read_csv(id3)
df4o = pd.read_csv(id4)
df5o = pd.read_csv(id5)
df6o = pd.read_csv(id6)
df7o = pd.read_csv(id7)
df8o = pd.read_csv(id8)
df9o = pd.read_csv(id9)
df10o = pd.read_csv(id10)

df10o
# Out:
#                 t         xh         yh         zh       vxh       vyh  \
# 0             0.0   4.913468 -31.886966   1.991604  0.003156 -0.000146
# 1        365250.0  13.180904 -31.342850  -0.478250  0.002965  0.000539
# 2        730500.0  19.642578 -29.555161  -2.552797  0.002708  0.001036
# 3       1095750.0  25.031516 -26.988829  -4.398293  0.002404  0.001408
# 4       1461000.0  29.599166 -23.853609  -6.069889  0.002101  0.001680
# ...           ...        ...        ...        ...       ...       ...
# 996   363789000.0 -33.872957 -18.991621  -1.768166  0.000767 -0.002556
# 997   364154250.0 -31.316790 -25.287133  -3.843917  0.001185 -0.002277
# 998   364519500.0 -27.134480 -31.645590  -6.113765  0.001554 -0.001903
# 999   364884750.0 -21.075023 -37.497413  -8.443195  0.001866 -0.001460
# 1000  365250000.0 -12.544823 -42.419395 -10.754708  0.002120 -0.000896
#
#             vz
# 0    -0.000899
# 1    -0.000917
# 2    -0.000893
# 3    -0.000847
# 4    -0.000788
# ...        ...
# ...

# %%
rn = np.sqrt((df10['rx']**2)+(df10['ry']**2)+(df10['rz']**2))
ro = np.sqrt((df10o['xh']**2)+(df10o['yh']**2)+(df10o['zh']**2))

plt.plot(df10['t'], np.abs(ro-rn))

# %%
vn = np.sqrt((df10['vx']**2)+(df10['vy']**2)+(df10['vz']**2))
vo = np.sqrt((df10o['vxh']**2)+(df10o['vyh']**2)+(df10o['vz']**2))

plt.plot(df10['t'], np.abs(vo-vn))
